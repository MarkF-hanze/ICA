# %%
import pandas as pd

# %%
df = pd.read_csv('/home/MarkF/Downloads/ICA_components.csv', index_col=0)
df
# Out:
#         consensus independent component 1  consensus independent component 2  \
# 2597                            -0.206983                          -1.087045
# 60                               0.501158                           0.165651
# 780                             -0.295855                          -0.673554
# 3310                            -0.571206                          -0.934084
# 2978                             0.285105                           0.301577
# ...                                   ...                                ...
# 338579                          -0.627380                          -0.545751
# 417                             -0.410729                          -0.450551
# 83734                           -0.419421                          -3.083842
# 400759                           0.117069                           1.311618
# 9512                             0.277533                          -0.646802
#
# ...

# %%
import numpy as np
expression = []
s = np.random.normal(0, 10, 4) 
for x in range(0,1000):
    s = np.random.normal(s[np.random.randint(0,4)], 1, 19635) 
    expression.append(s)

# %%
pd.DataFrame(expression)
# Out:
#          0          1          2          3          4          5      \
# 0    -0.645974  -1.174238  -0.304347   2.146617  -0.593446   0.266884
# 1     1.506349   2.442970   0.962371   0.916944   2.629371   2.174297
# 2     1.925991   2.276702   2.009511   0.393472  -0.025753   1.292075
# 3    -1.250050   0.967543   0.005510   0.101455   0.814039   0.726738
# 4     0.081171   0.146035   1.053492   0.818072   0.565825   1.500036
# ..         ...        ...        ...        ...        ...        ...
# 995 -27.016820 -25.110210 -26.794730 -24.016036 -25.416609 -24.792736
# 996 -27.806538 -25.680199 -25.813302 -25.886050 -27.286227 -27.046327
# 997 -26.562537 -25.908912 -26.836390 -24.867113 -25.027847 -25.281298
# 998 -27.324095 -26.626942 -27.041908 -25.796425 -24.567919 -26.344165
# 999 -26.621963 -26.822726 -25.536172 -26.290902 -26.532053 -28.108473
#
#          6          7          8          9      ...      19625      19626  \
# ...
