# %%
from dask import dataframe as dd

# %%
from dask.distributed import Client
client = Client(n_workers=25, threads_per_worker=2, processes=True, memory_limit='10GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:40789' processes=25 threads=50, memory=232.83 GiB>

# %%
dask_df = dd.read_csv('/home/MarkF/DivideConquer/Results/Cancer_Types_Norm/AllCancer.csv').drop('Unnamed: 0', axis=1)

# %%
dask_df.head()
# Out:
#        2597        60       780      3310      2978      7318      2101  \
# 0 -1.183025  0.362483  0.255996 -0.031788 -0.445254  0.438165 -0.224108
# 1 -1.462245  0.488861  0.021698 -0.000731 -0.467282  0.634887 -0.291175
# 2 -1.445063  0.225646  0.157055 -0.150877 -0.235915  0.476489 -0.052552
# 3 -1.236524  0.259395  0.125881  0.099799 -0.562043  0.175257 -0.932817
# 4 -0.917861  0.078678  0.097902 -0.039454 -0.552215  0.329176 -0.247283
#
#        2621     10594       826  ...    440896  101926928  101929076  \
# 0  1.474252  0.538604  0.910850  ... -0.740208  -0.545541  -0.251143
# 1  1.729448  0.786433  0.858247  ... -1.373403  -1.511938  -0.834303
# 2  1.656621  0.886775  0.849115  ... -0.699441  -1.065165  -0.577625
# 3  1.099559  0.645843  0.271974  ... -0.288310  -0.853402  -0.137629
# 4  1.683430  0.679784  0.828407  ... -0.617502  -0.577133  -0.314123
#
#      643201    643365    338579       417     83734    400759      9512
# 0 -0.716089 -0.742225 -0.883163 -0.687989  1.090785  0.016351 -0.685448
# 1 -0.679645 -0.837417 -1.309017 -1.012565  1.094518 -0.275871 -0.787445
# 2 -0.509600 -0.702643 -1.043817 -0.628581  0.565940 -0.476249 -0.861886
# 3 -0.509122  0.381609  0.180969 -0.248954  0.071519  0.059917 -0.216640
# 4 -0.180203 -0.701128 -0.640899 -1.142845  0.634619  0.648637 -1.603068
#
# [5 rows x 19635 columns]

# %%
m1 = dask_df.mean().compute()
sd1 = dask_df.std().compute()
# Out:
# distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:44571 -> tcp://127.0.0.1:34041
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 1719, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:44571 remote=tcp://127.0.0.1:51836>: TimeoutError: [Errno 110] Connection timed out
# distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:34931 -> tcp://127.0.0.1:36087
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 1719, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:34931 remote=tcp://127.0.0.1:42628>: TimeoutError: [Errno 110] Connection timed out
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44571
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4232, in _get_data
#     response = await send_recv(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 663, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:51836 remote=tcp://127.0.0.1:44571>: ConnectionResetError: [Errno 104] Connection reset by peer
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34931
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4232, in _get_data
#     response = await send_recv(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 663, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42628 remote=tcp://127.0.0.1:34931>: ConnectionResetError: [Errno 104] Connection reset by peer
# distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36087 -> tcp://127.0.0.1:34041
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 1719, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36087 remote=tcp://127.0.0.1:45966>: TimeoutError: [Errno 110] Connection timed out
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36087
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4232, in _get_data
#     response = await send_recv(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 663, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 221, in read
#     convert_stream_closed_error(self, e)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:45966 remote=tcp://127.0.0.1:36087>: ConnectionResetError: [Errno 104] Connection reset by peer
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35145
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:35145 after 30 s

# %%
dask_df_1 = dd.read_csv('/home/MarkF/DivideConquer/Results/Cancer_Types_Norm/GPL570_norm.dat',
                     sep=None, engine='python', header=None)

# %%
dask_df_1.head()
# Out:
#       0         1         2         3         4         5         6      \
# 0 -1.183025  0.362483  0.255996 -0.031788 -0.445254  0.438165 -0.224108
# 1 -1.462245  0.488861  0.021698 -0.000731 -0.467282  0.634887 -0.291175
# 2 -1.445063  0.225646  0.157055 -0.150877 -0.235915  0.476489 -0.052552
# 3 -1.236524  0.259395  0.125881  0.099799 -0.562043  0.175257 -0.932817
# 4 -0.917861  0.078678  0.097902 -0.039454 -0.552215  0.329176 -0.247283
#
#       7         8         9      ...     19625     19626     19627     19628  \
# 0  1.474252  0.538604  0.910850  ... -0.740208 -0.545541 -0.251143 -0.716089
# 1  1.729448  0.786433  0.858247  ... -1.373403 -1.511938 -0.834303 -0.679645
# 2  1.656621  0.886775  0.849115  ... -0.699441 -1.065165 -0.577625 -0.509600
# 3  1.099559  0.645843  0.271974  ... -0.288310 -0.853402 -0.137629 -0.509122
# 4  1.683430  0.679784  0.828407  ... -0.617502 -0.577133 -0.314123 -0.180203
#
#       19629     19630     19631     19632     19633     19634
# 0 -0.742225 -0.883163 -0.687989  1.090785  0.016351 -0.685448
# 1 -0.837417 -1.309017 -1.012565  1.094518 -0.275871 -0.787445
# 2 -0.702643 -1.043817 -0.628581  0.565940 -0.476249 -0.861886
# 3  0.381609  0.180969 -0.248954  0.071519  0.059917 -0.216640
# 4 -0.701128 -0.640899 -1.142845  0.634619  0.648637 -1.603068
#
# [5 rows x 19635 columns]

# %%
m2 = dask_df_1.mean().compute()
sd2 = dask_df_1.std().compute()
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46313
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:46313 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40531
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:40531 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45053
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 196, in read
#     async def read(self, deserializers=None):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 319, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:45053 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44571
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 196, in read
#     async def read(self, deserializers=None):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 319, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:44571 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33569
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 196, in read
#     async def read(self, deserializers=None):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 319, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33569 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43561
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:43561 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33157
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:33157 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44261
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:44261 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45105
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:45105 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40531
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:40531 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40889
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:40889 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42873
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:42873 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44875
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:44875 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46313
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:46313 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45473
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:45473 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42873
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:42873 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44571
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:44571 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34931
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:34931 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40889
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:40889 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33569
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:33569 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45105
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:45105 after 30 s
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38841
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 245, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 452, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 320, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 454, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 324, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:38841 after 30 s
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33157
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/tcp.py", line 398, in connect
#     stream = await self.client.connect(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 284, in connect
#     comm = await asyncio.wait_for(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 2962, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4252, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/worker.py", line 4229, in _get_data
#     comm = await rpc.connect(worker)
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1071, in connect
#     raise exc
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/core.py", line 1055, in connect
#     comm = await fut
#   File "/home/MarkF/.conda/envs/Code/lib/python3.9/site-packages/distributed/comm/core.py", line 308, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:33157 after 30 s
